# %%
test
###s  # 🔊 [voice note: voice_f3d48c97_line2_1781133939257.webm]

# %%
import os
os.listdir('.')
# Out:
# ['.copier-answers.yml',
#  '.github',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.prettierignore',
#  '.virtual_documents',
#  '.yarn',
#  '.yarnrc.yml',
#  'AGENTS.md',
#  'CHANGELOG.md',
#  'CLAUDE.md',
#  'CONTRIBUTING.md',
#  'eslint.config.mjs',
#  'install.json',
#  'lib',
#  'LICENSE',
#  'node_modules',
#  'package.json',
#  'pyproject.toml',
#  'README.md',
#  'RELEASE.md',
#  'schema',
#  'setup.py',
#  'src',
#  'style',
#  'tsconfig.json',
#  'tsconfig.tsbuildinfo',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'voicecell',
#  'yarn.lock']

# %%
  # 🔊 [voice note: voice_887df969_line1_1781135522638.webm]

# %%
  # 🔊 vm_3 [voice_7ebd9479_line1_1781166411728.webm]

# %%
  # 🔊 vm_4 [1781168202254]
  # 🔊 vm_5 [1781168207761]
