# %%
# !jupyter labextension list
# Out:
# JupyterLab v4.0.11
# C:\Users\Victus\AppData\Roaming\jupyter\labextensions
#         voicecell v0.1.0 enabled ok
#
# C:\ProgramData\anaconda3\share\jupyter\labextensions
#         jupyterlab-plotly v5.22.0 enabled  X
#         @anaconda/assistant v4.0.15 enabled ok (python, aext_assistant)
#         @anaconda/core v4.0.15 enabled ok (python, aext_core)
#         @anaconda/panels v4.0.15 enabled ok (python, aext_panels)
#         @anaconda/share_notebook v4.0.15 enabled ok (python, aext_share_notebook)
#         @jupyter-notebook/lab-extension v7.0.8 enabled ok
#         @jupyter-widgets/jupyterlab-manager v3.0.0 enabled  X (python, jupyterlab_widgets)
#         @lckr/jupyterlab_variableinspector v3.1.0 enabled ok (python, lckr_jupyterlab_variableinspector)
#         @pyviz/jupyterlab_pyviz v3.0.2 enabled ok
#
#
#    The following extensions are outdated:
#         jupyterlab-plotly
#         @jupyter-widgets/jupyterlab-manager
#
# ...

# %%
# !dir C:\Users\Victus\AppData\Roaming\jupyter\labextensions\voicecell
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8E17-2B05
#
#  Directory of C:\Users\Victus\AppData\Roaming\jupyter\labextensions\voicecell
#
# 06/10/2026  12:55 AM    <DIR>          .
# 06/10/2026  06:12 PM    <DIR>          ..
# 06/10/2026  12:55 AM            23,896 build_log.json
# 06/10/2026  12:55 AM             4,184 package.json
# 06/10/2026  12:55 AM    <DIR>          static
#                2 File(s)         28,080 bytes
#                3 Dir(s)  54,077,562,880 bytes free

# %%
# !dir C:\Users\Victus\AppData\Roaming\jupyter\labextensions\voicecell\schemas
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8E17-2B05
#
#  Directory of C:\Users\Victus\AppData\Roaming\jupyter\labextensions\voicecell
# File Not Found

# %%
# !dir C:\Users\Victus\Desktop\voice_api\voicecell\labextension
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8E17-2B05
#
#  Directory of C:\Users\Victus\Desktop\voice_api\voicecell\labextension
#
# 06/10/2026  07:46 PM    <DIR>          .
# 06/10/2026  02:37 AM    <DIR>          ..
# 06/10/2026  07:46 PM             4,309 package.json
# 06/10/2026  07:46 PM    <DIR>          schemas
# 06/10/2026  07:46 PM    <DIR>          static
#                1 File(s)          4,309 bytes
#                4 Dir(s)  55,338,078,208 bytes free
